# %%
from astropy.io import fits
import numpy as np
import matplotlib.pyplot as plt

# %%
data = 'C:/naiya_rye_/Autosave Image (Bias-Naiya-Rye)-0001.fit'

# %%
foo = fits.open(data)
foo.info()
bias_image = foo[0].data
bias_header = foo[0]
# Out:
# Filename: C:/naiya_rye_/Autosave Image (Bias-Naiya-Rye)-0001.fit
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      34   (4656, 3522)   int16 (rescales to uint16)

# %%
def actual_counts(bias_image):
    return bias_image/16+1
fixed_image = actual_counts(bias_image)

# %%
plt.imshow(fixed_image)
plt.colorbar(label='counts')
plt.title('Bias images: QHY 163M CMOS')
# Out:
# Text(0.5, 1.0, 'Bias images: QHY 163M CMOS')

# %%
plt.imshow(fixed_image[0:100,0:100])
plt.colorbar(label='counts')
plt.title('Bias images: QHY 163M CMOS')
# Out:
# Text(0.5, 1.0, 'Bias images: QHY 163M CMOS')
