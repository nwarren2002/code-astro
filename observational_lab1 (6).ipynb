# %%
import glob
import numpy as np
from astropy.io import fits
import matplotlib.pyplot as plt
import os

# %%
def actual_counts(bias_image):
    return bias_image / 16 + 1

# %%
directory_path = 'C:/naiya_rye_ - Copy/Bias'

# %%
bias_images = glob.glob(os.path.join(directory_path, "*.fit"))

image_data_list = []

# %%
for file in bias_images:
    with fits.open(file) as foo:
        foo.info()
        bias_image = foo[0].data  
        fixed_image = actual_counts(bias_image)
        image_data_list.append(fixed_image)
# Out:
# Filename: C:/naiya_rye_ - Copy/Bias\Autosave Image (Bias-Naiya-Rye)-0001.fit
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      34   (4656, 3522)   int16 (rescales to uint16)
# Filename: C:/naiya_rye_ - Copy/Bias\Autosave Image (Bias-Naiya-Rye)-0002.fit
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      34   (4656, 3522)   int16 (rescales to uint16)
# Filename: C:/naiya_rye_ - Copy/Bias\Autosave Image (Bias-Naiya-Rye)-0003.fit
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      34   (4656, 3522)   int16 (rescales to uint16)
# Filename: C:/naiya_rye_ - Copy/Bias\Autosave Image (Bias-Naiya-Rye)-0004.fit
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      34   (4656, 3522)   int16 (rescales to uint16)
# Filename: C:/naiya_rye_ - Copy/Bias\Autosave Image (Bias-Naiya-Rye)-0005.fit
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      34   (4656, 3522)   int16 (rescales to uint16)
# Filename: C:/naiya_rye_ - Copy/Bias\Autosave Image (Bias-Naiya-Rye)-0006.fit
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      34   (4656, 3522)   int16 (rescales to uint16)
# Filename: C:/naiya_rye_ - Copy/Bias\Autosave Image (Bias-Naiya-Rye)-0007.fit
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      34   (4656, 3522)   int16 (rescales to uint16)
# Filename: C:/naiya_rye_ - Copy/Bias\Autosave Image (Bias-Naiya-Rye)-0008.fit
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      34   (4656, 3522)   int16 (rescales to uint16)
# Filename: C:/naiya_rye_ - Copy/Bias\Autosave Image (Bias-Naiya-Rye)-0009.fit
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      34   (4656, 3522)   int16 (rescales to uint16)
# Filename: C:/naiya_rye_ - Copy/Bias\Autosave Image (Bias-Naiya-Rye)-0010.fit
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      34   (4656, 3522)   int16 (rescales to uint16)
# Filename: C:/naiya_rye_ - Copy/Bias\Autosave Image (Bias-Naiya-Rye)-0011.fit
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      34   (4656, 3522)   int16 (rescales to uint16)
# Filename: C:/naiya_rye_ - Copy/Bias\Autosave Image (Bias-Naiya-Rye)-0012.fit
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      34   (4656, 3522)   int16 (rescales to uint16)
# Filename: C:/naiya_rye_ - Copy/Bias\Autosave Image (Bias-Naiya-Rye)-0013.fit
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      34   (4656, 3522)   int16 (rescales to uint16)
# Filename: C:/naiya_rye_ - Copy/Bias\Autosave Image (Bias-Naiya-Rye)-0014.fit
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      34   (4656, 3522)   int16 (rescales to uint16)
# Filename: C:/naiya_rye_ - Copy/Bias\Autosave Image (Bias-Naiya-Rye)-0015.fit
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      34   (4656, 3522)   int16 (rescales to uint16)
# Filename: C:/naiya_rye_ - Copy/Bias\Autosave Image (Bias-Naiya-Rye)-0016.fit
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      34   (4656, 3522)   int16 (rescales to uint16)
# Filename: C:/naiya_rye_ - Copy/Bias\Autosave Image (Bias-Naiya-Rye)-0017.fit
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      34   (4656, 3522)   int16 (rescales to uint16)
# Filename: C:/naiya_rye_ - Copy/Bias\Autosave Image (Bias-Naiya-Rye)-0018.fit
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      34   (4656, 3522)   int16 (rescales to uint16)
# Filename: C:/naiya_rye_ - Copy/Bias\Autosave Image (Bias-Naiya-Rye)-0019.fit
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      34   (4656, 3522)   int16 (rescales to uint16)
# Filename: C:/naiya_rye_ - Copy/Bias\Autosave Image (Bias-Naiya-Rye)-0020.fit
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      34   (4656, 3522)   int16 (rescales to uint16)

# %%
image_data_stack = np.array(image_data_list)
average_image = np.mean(image_data_stack, axis=0)

# %%
plt.imshow(average_image, cmap='gray')
plt.colorbar(label='Counts')
plt.title('Average Bias Image')
plt.show()

# %%
#Median of that^
median_bias = np.median(average_image)
print(median_bias)
# Out:
# 153.65

# %%
#Below will be our twilight flat stuff

# %%
#Converting twilight data back to real
def actual_counts(twilight_flat):
    return twilight_flat / 16 + 1

# %%
directory_path_two = 'C:/naiya_rye_ - Copy/Twilights 30-40'

# %%
twilight_flats = glob.glob(os.path.join(directory_path, "*.fit"))

normalized_twilight_flats = []

# %%
#Loop for my flatz
for file in twilight_flats:
    with fits.open(file) as foo:
        twilight_image = foo[0].data
        
        normalized_flat = (twilight_image - average_image) / median_bias
        
        normalized_twilight_flats.append(normalized_flat)

# %%
plt.imshow(normalized_twilight_flats[0], cmap='gray', origin='lower')
plt.colorbar()  
plt.title('Normalized Twilight Flat')
plt.show()

# %%
# Median flats- have to use 32 instead of 64 because low RAM lol
normalized_twilight_stack = np.array(normalized_twilight_flats, dtype=np.float32)

# Median value
median_normalized_twilight_flat = np.median(normalized_twilight_stack, axis=0)

# Plot the median normalized twilight flat
import matplotlib.pyplot as plt
plt.imshow(median_normalized_twilight_flat, cmap='gray', origin='lower')
plt.colorbar()
plt.title('Median Normalized Twilight Flat')
plt.show()

# %%
#Below are darks
#I pretty much just did what we did for the bias images

# %%
dark_images_path = 'C:/naiya_rye_ - Copy/Darks 3s'
dark_images_3s = glob.glob(dark_images_path + '*.fit')

darks_list_3s = []

def actual_counts(dark_image_3s):
    return dark_image_3s / 16 + 1  

for file in dark_images_3s:
    with fits.open(file) as foo:
        foo.info()
        dark_image_3s = foo[0].data  
        fixed_image_3s = actual_counts(dark_image_3s)
        darks_list_3s.append(fixed_image_3s)
# Out:
# Filename: C:/naiya_rye_ - Copy\Darks 3s right this time-0001.fit
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      34   (4656, 3522)   int16 (rescales to uint16)
# Filename: C:/naiya_rye_ - Copy\Darks 3s right this time-0002.fit
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      34   (4656, 3522)   int16 (rescales to uint16)
# Filename: C:/naiya_rye_ - Copy\Darks 3s right this time-0003.fit
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      34   (4656, 3522)   int16 (rescales to uint16)
# Filename: C:/naiya_rye_ - Copy\Darks 3s right this time-0004.fit
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      34   (4656, 3522)   int16 (rescales to uint16)
# Filename: C:/naiya_rye_ - Copy\Darks 3s right this time-0005.fit
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      34   (4656, 3522)   int16 (rescales to uint16)
# Filename: C:/naiya_rye_ - Copy\Darks 3s right this time-0006.fit
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      34   (4656, 3522)   int16 (rescales to uint16)
# Filename: C:/naiya_rye_ - Copy\Darks 3s right this time-0007.fit
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      34   (4656, 3522)   int16 (rescales to uint16)
# Filename: C:/naiya_rye_ - Copy\Darks 3s right this time-0008.fit
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      34   (4656, 3522)   int16 (rescales to uint16)
# Filename: C:/naiya_rye_ - Copy\Darks 3s right this time-0009.fit
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      34   (4656, 3522)   int16 (rescales to uint16)
# Filename: C:/naiya_rye_ - Copy\Darks 3s right this time-0010.fit
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      34   (4656, 3522)   int16 (rescales to uint16)
# Filename: C:/naiya_rye_ - Copy\Darks 3s-0001.fit
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      34   (4656, 3522)   int16 (rescales to uint16)
# Filename: C:/naiya_rye_ - Copy\Darks 3s-0002.fit
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      34   (4656, 3522)   int16 (rescales to uint16)
# Filename: C:/naiya_rye_ - Copy\Darks 3s-0003.fit
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      34   (4656, 3522)   int16 (rescales to uint16)
# Filename: C:/naiya_rye_ - Copy\Darks 3s-0004.fit
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      34   (4656, 3522)   int16 (rescales to uint16)
# Filename: C:/naiya_rye_ - Copy\Darks 3s-0005.fit
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      34   (4656, 3522)   int16 (rescales to uint16)
# Filename: C:/naiya_rye_ - Copy\Darks 3s-0006.fit
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      34   (4656, 3522)   int16 (rescales to uint16)
# Filename: C:/naiya_rye_ - Copy\Darks 3s-0007.fit
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      34   (4656, 3522)   int16 (rescales to uint16)
# Filename: C:/naiya_rye_ - Copy\Darks 3s-0008.fit
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      34   (4656, 3522)   int16 (rescales to uint16)
# Filename: C:/naiya_rye_ - Copy\Darks 3s-0009.fit
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      34   (4656, 3522)   int16 (rescales to uint16)
# Filename: C:/naiya_rye_ - Copy\Darks 3s-0010.fit
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      34   (4656, 3522)   int16 (rescales to uint16)

# %%
dark_stack_3s = np.array(darks_list_3s)
average_dark_image = np.mean(dark_stack_3s, axis=0)

# %%
  plt.imshow(average_dark_image, cmap='gray')
plt.colorbar()
plt.title("Average Dark Image")
plt.show()

# %%
dark_images_path_10s = "C:/naiya_rye_ - Copy/Darks 10s"
#"C:/naiya_rye_ - Copy/Darks 10s"
dark_images_10s = glob.glob(dark_images_path_10s + '*.fit')

darks_10s_list = []

def actual_counts(dark_image_10s ):
    return dark_image_10s / 16 + 1 

for file in dark_images_10s:
    with fits.open(file) as foo:
        foo.info()
        dark_image_10s = foo[0].data  
        fixed_image_10s = actual_counts(dark_image_10s)
        darks_10s_list.append(fixed_image_10s)
# Out:
# Filename: C:/naiya_rye_ - Copy\Darks 10s-0001.fit
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      34   (4656, 3522)   int16 (rescales to uint16)
# Filename: C:/naiya_rye_ - Copy\Darks 10s-0002.fit
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      34   (4656, 3522)   int16 (rescales to uint16)
# Filename: C:/naiya_rye_ - Copy\Darks 10s-0003.fit
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      34   (4656, 3522)   int16 (rescales to uint16)
# Filename: C:/naiya_rye_ - Copy\Darks 10s-0004.fit
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      34   (4656, 3522)   int16 (rescales to uint16)
# Filename: C:/naiya_rye_ - Copy\Darks 10s-0005.fit
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      34   (4656, 3522)   int16 (rescales to uint16)
# Filename: C:/naiya_rye_ - Copy\Darks 10s-0006.fit
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      34   (4656, 3522)   int16 (rescales to uint16)
# Filename: C:/naiya_rye_ - Copy\Darks 10s-0007.fit
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      34   (4656, 3522)   int16 (rescales to uint16)
# Filename: C:/naiya_rye_ - Copy\Darks 10s-0008.fit
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      34   (4656, 3522)   int16 (rescales to uint16)
# Filename: C:/naiya_rye_ - Copy\Darks 10s-0009.fit
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      34   (4656, 3522)   int16 (rescales to uint16)
# Filename: C:/naiya_rye_ - Copy\Darks 10s-0010.fit
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      34   (4656, 3522)   int16 (rescales to uint16)

# %%
dark_stack_10s = np.array(darks_10s_list)
average_dark_image_10s = np.mean(dark_stack_10s, axis=0)

# %%
plt.imshow(average_dark_image_10s, cmap='gray')
plt.colorbar()
plt.title("Average Dark Image")
plt.show()

# %%
def actual_counts(image):
    return image / 16 + 1
    
bias_file_1 = r"C:\naiya_rye_ - Copy/Bias/Autosave Image (Bias-Naiya-Rye)-0001.fit"
bias_file_2 = r"C:/naiya_rye_ - Copy/Bias/Autosave Image (Bias-Naiya-Rye)-0002.fit"

with fits.open(bias_file_1) as bias1:
    bias_image1 = bias1[0].data

bias_image1_corrected = actual_counts(bias_image1)

with fits.open(bias_file_2) as bias2:
    bias_image2 = bias2[0].data

bias_image2_corrected = actual_counts(bias_image2)

difference_in_bias = bias_image1_corrected - bias_image2_corrected

pixel_variations = difference_in_bias.flatten()

# %%
plt.hist(pixel_variations, bins=100, color='gray')
plt.title('Pixel to Pixel Variation')
plt.xlabel('Pixel Val Diff')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
sigma_read = np.std(pixel_variations)/np.sqrt(2)

# %%
science_image_file = "C:/naiya_rye_ - Copy/Deneb_Naiya_Rye2.fit"
with fits.open(science_image_file) as data_science:
    science_image_data = data_science[0].data 

science_image_corrected_b = science_image_data - average_image
average_dark_image_c = average_dark_image - average_image
science_image_corrected_d = science_image_corrected_b - average_dark_image
science_image_calibrated = science_image_corrected_d / normalized_flat

deneb = np.zeros_like(science_image_calibrated) # thresholded values
star_median = np.median(science_image_calibrated) # median of the star


for i in range(len(science_image_calibrated[:, 0])):
    for j in range(len(science_image_calibrated[0, :])):
        star_val = science_image_calibrated[i, j] 
        if star_val >= star_median:
            deneb[i, j] = 1                    
        else:
            deneb[i, j] = 0                      


plt.imshow(deneb, cmap='gray')
plt.title('Deneb Image')
plt.colorbar()
plt.show()

# %%
science_image_file_2 = "C:/naiya_rye_ - Copy/Rye_Naiya new_aq2.fit"
with fits.open(science_image_file_2) as data_science_2:
    science_image_data_2 = data_science_2[0].data 
    
science_image_corrected_b_2 = science_image_data_2 - average_image
average_dark_image_c_2 = average_dark_image_10s - average_image
science_image_corrected_d_2 = science_image_corrected_b_2 - average_dark_image_c_2
science_image_calibrated_2 = science_image_corrected_d_2 / normalized_flat


nu_aquari = np.zeros_like(science_image_calibrated_2) 
star_median_2 = np.median(science_image_calibrated_2)  

for i in range(len(science_image_calibrated_2[:, 0])):
    for j in range(len(science_image_calibrated_2[0, :])):
        star_val_2 = science_image_calibrated_2[i, j]    
        if star_val_2 >= star_median_2:
            nu_aquari[i, j] = 1                       
        else:
            nu_aquari[i, j] = 0

# %%
plt.imshow(nu_aquari, cmap='gray')
plt.title('Nu Aquari')
plt.colorbar()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 plt.imshow(nu_aquari, cmap='gray')
#       2 plt.title('Nu Aquari')
#       3 plt.colorbar()
#
# NameError: name 'plt' is not defined
